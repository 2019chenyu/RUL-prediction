# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
% matplotlib inline
plt.rcParams['font.sans-serif'] = ['SimHei'] # 显示中文字符
font1 = {'weight' : 'normal','size': 23}
font2 = {'weight' : 'normal','size': 18}
mpl.style.use('ggplot')

# %%
train_fd001_path = r'../data/train_FD001.txt'
train_fd001 = pd.read_csv(train_fd001_path,sep=" ", header=None)
train_fd001.drop(train_fd001.columns[[26, 27]], axis=1, inplace=True) #这两列为空，删除
train_fd001.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# %%
train_fd002_path = r'../data/train_FD002.txt'
train_fd002 = pd.read_csv(train_fd002_path,sep=" ", header=None)
train_fd002.drop(train_fd002.columns[[26, 27]], axis=1, inplace=True) #这两列为空，删除
train_fd002.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# %%
train_fd003_path = r'../data/train_FD003.txt'
train_fd003 = pd.read_csv(train_fd003_path,sep=" ", header=None)
train_fd003.drop(train_fd003.columns[[26, 27]], axis=1, inplace=True) #这两列为空，删除
train_fd003.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# %%
train_fd004_path = r'../data/train_FD004.txt'
train_fd004 = pd.read_csv(train_fd004_path,sep=" ", header=None)
train_fd004.drop(train_fd004.columns[[26, 27]], axis=1, inplace=True) #这两列为空，删除
train_fd004.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# %%
train_all = pd.concat([train_fd001, train_fd002, train_fd003, train_fd004], axis=0)

# %%
train_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160359 entries, 0 to 61248
# Data columns (total 26 columns):
# id          160359 non-null int64
# cycle       160359 non-null int64
# setting1    160359 non-null float64
# setting2    160359 non-null float64
# setting3    160359 non-null float64
# s1          160359 non-null float64
# s2          160359 non-null float64
# s3          160359 non-null float64
# s4          160359 non-null float64
# s5          160359 non-null float64
# s6          160359 non-null float64
# s7          160359 non-null float64
# s8          160359 non-null float64
# s9          160359 non-null float64
# s10         160359 non-null float64
# s11         160359 non-null float64
# s12         160359 non-null float64
# s13         160359 non-null float64
# s14         160359 non-null float64
# s15         160359 non-null float64
# s16         160359 non-null float64
# s17         160359 non-null int64
# s18         160359 non-null int64
# ...

# %%
#显示所有列
pd.set_option('display.max_columns', None)
#显示所有行
pd.set_option('display.max_rows', None)
#设置value的显示长度为100，默认为50
pd.set_option('max_colwidth',100)

train_all.describe()
# Out:
#                   id          cycle       setting1       setting2  \
# count  160359.000000  160359.000000  160359.000000  160359.000000
# mean      105.553758     123.331338      17.211973       0.410004
# std        72.867325      83.538146      16.527988       0.367938
# min         1.000000       1.000000      -0.008700      -0.000600
# 25%        44.000000      57.000000       0.001300       0.000200
# 50%        89.000000     114.000000      19.998100       0.620000
# 75%       164.000000     173.000000      35.001500       0.840000
# max       260.000000     543.000000      42.008000       0.842000
#
#             setting3             s1             s2             s3  \
# count  160359.000000  160359.000000  160359.000000  160359.000000
# mean       95.724344     485.840890     597.361022    1467.035653
# std        12.359044      30.420388      42.478516     118.175261
# min        60.000000     445.000000     535.480000    1242.670000
# ...
