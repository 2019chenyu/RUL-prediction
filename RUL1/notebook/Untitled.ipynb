# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
# %matplotlib inline
mpl.style.use('ggplot')

font1 = {'family' : 'Times New Roman' , 'weight' : 'normal','size': 23}
font2 = {'family' : 'Times New Roman' , 'weight' : 'normal','size': 18}

# %%
x1 = np.array([11.952680587768555, 13.846665382385254, 12.604480743408203, 12.246306419372559, 13.564918518066406, 13.706414222717285, 13.283525466918945, 14.364347457885742, 12.831809043884277, 13.509570121765137, 14.17723560333252, 12.697059631347656, 12.574825286865234, 14.610234260559082, 12.217324256896973, 11.579085350036621, 12.686707496643066, 11.261177062988281, 11.12126350402832, 11.785929679870605])
x = np.arange(len(x1))

# %%
plt.figure(figsize=(20,10))
plt.plot(x, x1, 'o-', color='red', label='train')
plt.legend(prop=font2)
plt.xlabel('',font1)
plt.ylabel('rmse',font1)
plt.show()
